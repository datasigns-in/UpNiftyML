# %% [markdown]
# <a href="https://colab.research.google.com/github/datasigns-in/UpNiftyML/blob/main/Intraday_1mNifty50Downloader_RunDaily.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
import urllib.parse
import pandas as pd
import pytz,os
import requests
import json ,requests
from  datetime import datetime,timedelta,time
TIME_ZONE = pytz.timezone('Asia/Kolkata')

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')


# Get today's date
today_date = datetime.now().strftime("%Y-%m-%d")

# Get today's date as a string.
today_str = datetime.now().strftime("%Y%m%d")

# Create the folder path
folder_path = f'/content/drive/MyDrive/Nifty50DataAutoUpstox/1m_6mFrom17032024/{today_date}'

# Create the folder if it doesn't exist
if not os.path.exists(folder_path):
  # !mkdir -p "{folder_path}"

fileUrl ='https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz'
symboldf = pd.read_csv(fileUrl)
nifty50 = symboldf.iloc[:1]
nifty50.tradingsymbol = "Nifty50"
nvix = symboldf.iloc[35:36]
nvix.tradingsymbol = "NVIX"
#symboldf['expiry'] = pd.to_datetime(symboldf['expiry']).apply(lambda x: x.date())
#symboldf = symboldf[symboldf.exchange == 'NSE_EQ']
eqCsv = pd.read_csv('/content/drive/MyDrive/Nifty50DataAutoUpstox/NIFTY50NSE.csv')
isinList = 'NSE_EQ|' + eqCsv[' ISIN NUMBER']
symboldf = symboldf[symboldf.instrument_key.isin(isinList)]

symboldf = symboldf.concat(nifty50)
symboldf = symboldf.concat(nvix)
symboldf
# Out:
# Mounted at /content/drive
# <ipython-input-2-31c4edcf34b8>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nifty50.tradingsymbol = "Nifty50"
# <ipython-input-2-31c4edcf34b8>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvix.tradingsymbol = "NVIX"
# <ipython-input-2-31c4edcf34b8>:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   symboldf = symboldf.append(nifty50)
# ...

# %%
#fromDate = (datetime.now(TIME_ZONE)  - timedelta(days=10000)) .strftime("%Y-%m-%d")
#fromDate

# %%
def getHistoricalData(symInfo):
    res = None
    try:
        parseInstrument = urllib.parse.quote(symInfo.instrument_key)
        fromDate = (datetime.now(TIME_ZONE)  - timedelta(days=1)) .strftime("%Y-%m-%d")
        todate = datetime.now(TIME_ZONE).strftime("%Y-%m-%d")
        url = f'https://api.upstox.com/v2/historical-candle/intraday/{parseInstrument}/1minute'
        #print(url)

        res = requests.get(url,headers={'accept': 'application/json',},params={},timeout=5.0)
        candleRes = res.json()

        if 'data' in candleRes and 'candles' in candleRes['data'] and  candleRes['data']['candles']:
            candleData = pd.DataFrame(candleRes['data']['candles'])
            candleData.columns = ['date','open','high','low', 'close','vol','oi']
            candleData['date'] = pd.to_datetime(candleData['date']).dt.tz_convert('Asia/Kolkata')
            candleData['symbol'] = symInfo.tradingsymbol
            print(symInfo.tradingsymbol, len(candleData))
            return candleData
        else:
            print('No data',symInfo.instrument_key, candleRes)
    except :
        print(f'Error in data fetch for {symInfo.instrument_key} {res} {e}')

# %%
getHistoricalData(symboldf.iloc[50])
# Out:
# 19496 2024-03-18 09:18:00+05:30    14.49    14.49    14.40    14.47      0
# 19497 2024-03-18 09:17:00+05:30    14.56    14.56    14.48    14.49      0
# 19498 2024-03-18 09:16:00+05:30    14.49    14.62    14.49    14.56      0
# 19499 2024-03-18 09:15:00+05:30    13.69    14.53    13.69    14.47      0
#
#        oi    symbol
# 0       0  ADANIENT
# 1       0  ADANIENT
# ...

# %%
# prompt: upload this dataset to google drive

#from google.colab import drive
#drive.mount('/content/drive')

finalDataDf.to_csv(f'{folder_path}/finalDataDf_{today_str}.csv')

# %%
isCsv = True
for symData in candledfList:
    try:
        filename = symData.iloc[0]['symbol']
        if isCsv :
            filename = f'{filename}_{today_str}.csv'
            symData.to_csv(f'{folder_path}/{filename}',index=False)
        else:
            filename = f'{filename}.parquet'
            symData.to_parquet(filename , engine='pyarrow')
    except Exception as e:
        print(f'Error {e}')

# %%
pd.read_parquet('C:\\Users\\eqEOD\\20MICRONS.parquet')

# %%
# prompt: parse candledfList first array as json

import json
import pandas as pd

candledfList_json = []
for i in symboldf.index:
    res = getHistoricalData(symboldf.loc[i])
    if res is not None: candledfList_json.append(json.dumps(res.to_dict(orient='records'), default=lambda x: x.strftime('%Y-%m-%d %H:%M:%S') if isinstance(x, pd.Timestamp) else x))

#candledfList_json = json.dumps(candledfList[0].to_dict(orient='records'), default=lambda x: x.strftime('%Y-%m-%d %H:%M:%S') if isinstance(x, pd.Timestamp) else x)
# Out:
# ADANIENT 375
# ADANIPORTS 375
# APOLLOHOSP 375
# ASIANPAINT 375
# AXISBANK 375
# BAJAJ-AUTO 375
# BAJAJFINSV 375
# BAJFINANCE 375
# BHARTIARTL 375
# BPCL 375
# BRITANNIA 375
# CIPLA 375
# COALINDIA 375
# DIVISLAB 375
# DRREDDY 375
# EICHERMOT 375
# GRASIM 375
# HCLTECH 375
# HDFCBANK 375
# HDFCLIFE 375
# HEROMOTOCO 375
# HINDALCO 375
# HINDUNILVR 375
# ICICIBANK 375
# INDUSINDBK 375
# INFY 375
# ITC 375
# JSWSTEEL 375
# KOTAKBANK 375
# LT 375
# LTIM 375
# M&M 375
# MARUTI 375
# NESTLEIND 375
# NTPC 375
# ONGC 375
# POWERGRID 375
# RELIANCE 375
# SBILIFE 375
# SBIN 375
# SUNPHARMA 375
# TATACONSUM 375
# TATAMOTORS 375
# TATASTEEL 375
# TCS 375
# TECHM 375
# TITAN 375
# ULTRACEMCO 375
# UPL 375
# WIPRO 375
# Nifty50 375
# NVIX 375

# %%
# prompt: upload all different json to google drive path /content/drive/MyDrive/Nifty50DataAutoUpstox/1m_6mFrom17032024/json

for i, candledf_json in enumerate(candledfList_json):
    filename = f'{folder_path}/{symboldf.iloc[i]["tradingsymbol"]}_{today_str}.json'
    with open(filename, 'w') as f:
        f.write(candledf_json)
